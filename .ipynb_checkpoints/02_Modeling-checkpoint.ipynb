# %% [markdown]
# # 2 Modeling<a id='2_Modeling'></a>

# %% [markdown]
# ## 2.1 Contents<a id='2.1_Contents'></a>
# * [2 Modeling](#2_Modeling)
#     * [2.1 Contents](#2.1_Contents)
#     * [2.2 Imports](#2.2_Imports)
#     * [2.3 Train Validation Split](#2.3_Train_validation)
#     * [2.4 Ploting Training examples](#2.4_Plot_Train)
#     * [2.5 Data Augmentation](#2.5_data_augmentation)
#     * [2.6 Define Flower Model](#2.6_flower_model)
#         * [2.6.1 Mobile Net V2](#2.6.1_MobileNetV2)
#         * [2.6.2 VGG16](#2.6.2_VGG16)
#         * [2.6.3 Resnet50](#2.6.3_resnet50)

# %% [markdown]
# ## 2.2 Imports<a id='2.2_Imports'></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import tensorflow.keras.layers as tfl
import re
import pathlib
import glob
import shutil
import os
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation, RandomZoom

# %%
#Creating folders to save results. If this breaks,create manually
PREPROCESS_FOLDER_PATH = 'preprocessed_data/'

# %% [markdown]
# ## 2.3 Train Validation Split<a id='2.3_Train_validation'></a>

# %%
BATCH_SIZE = 32
IMG_SIZE = (160, 160)
train_dataset = image_dataset_from_directory(PREPROCESS_FOLDER_PATH,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.2,
                                             subset='training',
                                             seed=42)
validation_dataset = image_dataset_from_directory(PREPROCESS_FOLDER_PATH,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.2,
                                             subset='validation',
                                             seed=42)
# Out:
# Found 733 files belonging to 10 classes.
# Using 587 files for training.
# Found 733 files belonging to 10 classes.
# Using 146 files for validation.

# %% [markdown]
# There are **733** images in total. Out of the 733, 80% have been used for training and the other 20% of validation

# %%
#Extracting Classnames from the train dataset
class_names = np.array(train_dataset.class_names)
print(class_names)
# Out:
# ['bougainvillea' 'daisies' 'garden_roses' 'gardenias' 'hibiscus'
#  'hydrangeas' 'lilies' 'orchids' 'peonies' 'tulip']

# %% [markdown]
# ## 2.4 Plot Images and Labels from the Train Dataset<a id='2.4_Plot_Train'></a>

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
#Running an Optimizing Algorithm to find a good allocation of the CPU
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 2.5 Data Augmentation<a id='2.5_data_augmentation'></a>

# %%
#Data Augmentation
def data_augmenter():
    '''
    Create a Sequential model composed of 3 layers
    Random Flip
    Random Rotate
    Random Zoom
    
    Returns:
        tf.keras.Sequential
    '''
    data_augmentation = tf.keras.Sequential()
    data_augmentation.add(RandomFlip('horizontal'))
    data_augmentation.add(RandomRotation(0.2))
    data_augmentation.add(RandomZoom(0.5, 0.2))
    
    return data_augmentation

# %%
#Initialize the augmenter
augmenter = data_augmenter()

# %%
#Plot the augmented data
data_augmentation = data_augmenter()

for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %% [markdown]
# ## 2.6 Define Flower Model<a id='2.6_flower_model'></a>

# %%
def flowers_model(image_shape=IMG_SIZE,
                  data_augmentation=data_augmenter(),
                  pretrained_model = tf.keras.applications.mobilenet_v2.MobileNetV2,
                  preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input,
                  num_classes = len(class_names)):
    ''' Define a tf.keras model for Multi classification out of the flowers model
    Arguments:
        image_shape -- Image width and height
        data_augmentation -- data augmentation function
        keras.applications -- Pretrainied Model
        keras.application.preprocess_input -- Preprocess the data
    Returns:
        tf.keras.model    '''    
    
    input_shape = image_shape + (3,)
        
    base_model = pretrained_model(input_shape=input_shape,
                                  include_top=False,
                                  weights='imagenet')
    
    # Freezing the Base model
    base_model.trainable = False 

    # Creating the Input layer as the same size as ImageNetV2
    inputs = tf.keras.Input(shape=input_shape) 
    
    # Data Augmemtation
    x = data_augmentation(inputs)
    
    # Preprocessing the data using the same weights as the pretrained model
    x = preprocess_input(x) 
    
    x = base_model(x, training=False)     
    x = tf.keras.layers.GlobalAveragePooling2D()(x) 
    x = tf.keras.layers.Dropout(0.2)(x)
     
    #Softmax for Multiclass    
    outputs = tf.keras.layers.Dense(num_classes, activation = 'softmax')(x)
    
    model = tf.keras.Model(inputs, outputs)
    
    return model

# %% [markdown]
# ### 2.6.1 MobileNetV2<a id='2.6.1_MobileNetV2'></a>

# %%
model_mobileNetv2 = flowers_model(IMG_SIZE, data_augmentation)

# %%
model_mobileNetv2.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential_1 (Sequential)   (None, 160, 160, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 160, 160, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 160, 160, 3)      0
#  a)
#
#  mobilenetv2_1.00_160 (Funct  (None, 5, 5, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 10)                12810
#
# =================================================================
# Total params: 2,270,794
# Trainable params: 12,810
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model_mobileNetv2.compile(optimizer=tf.keras.optimizers.Adam(lr = 0.001),
               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
               metrics=['accuracy'])
# Out:
# C:\Users\Neel Deorukhkar\Documents\Anaconda\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
initial_epochs = 40
history = model_mobileNetv2.fit(train_dataset, validation_data=validation_dataset, epochs=initial_epochs)
# Out:
# Epoch 1/40
# C:\Users\Neel Deorukhkar\Documents\Anaconda\lib\site-packages\tensorflow\python\util\dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 19/19 [==============================] - 9s 344ms/step - loss: 2.1669 - accuracy: 0.2675 - val_loss: 1.4158 - val_accuracy: 0.4726
# Epoch 2/40
# 19/19 [==============================] - 7s 328ms/step - loss: 1.1370 - accuracy: 0.6337 - val_loss: 0.9042 - val_accuracy: 0.7192
# Epoch 3/40
# 19/19 [==============================] - 7s 327ms/step - loss: 0.7932 - accuracy: 0.7700 - val_loss: 0.6852 - val_accuracy: 0.7945
# Epoch 4/40
# 19/19 [==============================] - 7s 328ms/step - loss: 0.6185 - accuracy: 0.8143 - val_loss: 0.6152 - val_accuracy: 0.8288
# Epoch 5/40
# 19/19 [==============================] - 7s 329ms/step - loss: 0.5359 - accuracy: 0.8416 - val_loss: 0.5657 - val_accuracy: 0.8151
# Epoch 6/40
# 19/19 [==============================] - 7s 326ms/step - loss: 0.4278 - accuracy: 0.8773 - val_loss: 0.5067 - val_accuracy: 0.8425
# Epoch 7/40
# 19/19 [==============================] - 7s 323ms/step - loss: 0.4127 - accuracy: 0.8842 - val_loss: 0.4921 - val_accuracy: 0.8630
# Epoch 8/40
# 19/19 [==============================] - 7s 326ms/step - loss: 0.3779 - accuracy: 0.8842 - val_loss: 0.4614 - val_accuracy: 0.8425
# Epoch 9/40
# 19/19 [==============================] - 7s 330ms/step - loss: 0.3601 - accuracy: 0.8995 - val_loss: 0.4233 - val_accuracy: 0.8562
# Epoch 10/40
# 19/19 [==============================] - 7s 330ms/step - loss: 0.3159 - accuracy: 0.8995 - val_loss: 0.4111 - val_accuracy: 0.8562
# Epoch 11/40
# 19/19 [==============================] - 7s 323ms/step - loss: 0.3033 - accuracy: 0.9114 - val_loss: 0.4209 - val_accuracy: 0.8630
# Epoch 12/40
# 19/19 [==============================] - 7s 326ms/step - loss: 0.2606 - accuracy: 0.9233 - val_loss: 0.4177 - val_accuracy: 0.8562
# Epoch 13/40
# 19/19 [==============================] - 7s 322ms/step - loss: 0.2492 - accuracy: 0.9284 - val_loss: 0.3824 - val_accuracy: 0.8767
# Epoch 14/40
# Epoch 35/40
# 19/19 [==============================] - 7s 322ms/step - loss: 0.1152 - accuracy: 0.9659 - val_loss: 0.2966 - val_accuracy: 0.8973
# Epoch 36/40
# 19/19 [==============================] - 7s 323ms/step - loss: 0.1230 - accuracy: 0.9744 - val_loss: 0.3068 - val_accuracy: 0.8836
# Epoch 37/40
# 19/19 [==============================] - 7s 326ms/step - loss: 0.1463 - accuracy: 0.9591 - val_loss: 0.3270 - val_accuracy: 0.8767
# Epoch 38/40
# 19/19 [==============================] - 7s 323ms/step - loss: 0.1096 - accuracy: 0.9727 - val_loss: 0.3088 - val_accuracy: 0.8904
# Epoch 39/40
# 19/19 [==============================] - 7s 328ms/step - loss: 0.1100 - accuracy: 0.9676 - val_loss: 0.3225 - val_accuracy: 0.8836
# Epoch 40/40
# 19/19 [==============================] - 7s 325ms/step - loss: 0.1233 - accuracy: 0.9574 - val_loss: 0.2995 - val_accuracy: 0.8973

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy - Mobile Net V2')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss - Mobile Net V2')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## 2.6.2 VGG16 <a id='2.6.2_VGG16'></a>

# %%
model_vgg16 = flowers_model(IMG_SIZE, data_augmentation,
                           pretrained_model = tf.keras.applications.vgg16.VGG16,
                           preprocess_input = tf.keras.applications.vgg16.preprocess_input)
model_vgg16.compile(optimizer=tf.keras.optimizers.Adam(lr = 0.001),
               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
               metrics=['accuracy'])
initial_epochs = 20
history_vgg16 = model_vgg16.fit(train_dataset, validation_data=validation_dataset, epochs=initial_epochs)
# Out:
# Epoch 1/20
# 19/19 [==============================] - 34s 2s/step - loss: 7.8762 - accuracy: 0.1244 - val_loss: 6.5328 - val_accuracy: 0.1301
# Epoch 2/20
# 19/19 [==============================] - 33s 2s/step - loss: 5.1757 - accuracy: 0.2300 - val_loss: 4.0337 - val_accuracy: 0.2808
# Epoch 3/20
# 19/19 [==============================] - 33s 2s/step - loss: 3.6640 - accuracy: 0.3646 - val_loss: 2.8719 - val_accuracy: 0.3973
# Epoch 4/20
# 19/19 [==============================] - 33s 2s/step - loss: 2.8021 - accuracy: 0.4361 - val_loss: 2.1702 - val_accuracy: 0.4932
# Epoch 5/20
# 19/19 [==============================] - 33s 2s/step - loss: 2.2623 - accuracy: 0.5247 - val_loss: 1.8034 - val_accuracy: 0.5890
# Epoch 6/20
# 19/19 [==============================] - 33s 2s/step - loss: 1.8372 - accuracy: 0.5622 - val_loss: 1.5383 - val_accuracy: 0.6301
# Epoch 7/20
# 19/19 [==============================] - 33s 2s/step - loss: 1.7517 - accuracy: 0.6048 - val_loss: 1.4159 - val_accuracy: 0.6781
# Epoch 8/20
# 19/19 [==============================] - 33s 2s/step - loss: 1.6300 - accuracy: 0.6405 - val_loss: 1.3094 - val_accuracy: 0.6781
# Epoch 9/20
# 19/19 [==============================] - 33s 2s/step - loss: 1.3409 - accuracy: 0.6508 - val_loss: 1.1488 - val_accuracy: 0.7329
# Epoch 10/20
# 19/19 [==============================] - 33s 2s/step - loss: 1.2839 - accuracy: 0.6831 - val_loss: 1.1069 - val_accuracy: 0.7740
# Epoch 11/20
# 19/19 [==============================] - 33s 2s/step - loss: 1.2285 - accuracy: 0.7002 - val_loss: 1.0434 - val_accuracy: 0.7534
# Epoch 12/20
# 19/19 [==============================] - 33s 2s/step - loss: 0.9859 - accuracy: 0.7359 - val_loss: 0.9487 - val_accuracy: 0.7740
# Epoch 13/20
# 19/19 [==============================] - 34s 2s/step - loss: 1.0342 - accuracy: 0.7257 - val_loss: 0.9233 - val_accuracy: 0.7945
# Epoch 14/20
# 19/19 [==============================] - 33s 2s/step - loss: 0.8735 - accuracy: 0.7666 - val_loss: 0.8519 - val_accuracy: 0.8082
# Epoch 15/20
# 19/19 [==============================] - 33s 2s/step - loss: 1.0237 - accuracy: 0.7462 - val_loss: 0.8702 - val_accuracy: 0.8219
# Epoch 16/20
# 19/19 [==============================] - 33s 2s/step - loss: 0.8650 - accuracy: 0.7734 - val_loss: 0.8570 - val_accuracy: 0.7945
# Epoch 17/20
# 19/19 [==============================] - 33s 2s/step - loss: 0.8345 - accuracy: 0.7547 - val_loss: 0.7664 - val_accuracy: 0.7877
# Epoch 18/20
# 19/19 [==============================] - 33s 2s/step - loss: 0.7973 - accuracy: 0.7700 - val_loss: 0.7550 - val_accuracy: 0.7877
# Epoch 19/20
# 19/19 [==============================] - 33s 2s/step - loss: 0.7208 - accuracy: 0.7802 - val_loss: 0.8012 - val_accuracy: 0.7808
# Epoch 20/20
# 19/19 [==============================] - 33s 2s/step - loss: 0.6658 - accuracy: 0.8075 - val_loss: 0.7780 - val_accuracy: 0.8014

# %% [markdown]
# #### Ploting Accuracy and Validation Loss

# %%
acc = [0.] + history_vgg16.history['accuracy']
val_acc = [0.] + history_vgg16.history['val_accuracy']

loss = history_vgg16.history['loss']
val_loss = history_vgg16.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy - VGG16')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss - VGG16')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## 2.6.3 ResNet50 <a id='2.6.3_resnet50'></a>

# %%
model_resnet50 = flowers_model(IMG_SIZE, data_augmentation,
                           pretrained_model = tf.keras.applications.resnet50.ResNet50,
                           preprocess_input = tf.keras.applications.resnet50.preprocess_input)
model_resnet50.compile(optimizer=tf.keras.optimizers.Adam(lr = 0.001),
               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
               metrics=['accuracy'])
initial_epochs = 40
history_resnet50 = model_resnet50.fit(train_dataset, validation_data=validation_dataset, epochs=initial_epochs)
# Out:
# Epoch 1/40
# 19/19 [==============================] - 19s 849ms/step - loss: 2.2008 - accuracy: 0.2998 - val_loss: 0.9495 - val_accuracy: 0.7260
# Epoch 2/40
# 19/19 [==============================] - 17s 819ms/step - loss: 0.9546 - accuracy: 0.6797 - val_loss: 0.6421 - val_accuracy: 0.7740
# Epoch 3/40
# 19/19 [==============================] - 17s 818ms/step - loss: 0.6111 - accuracy: 0.7973 - val_loss: 0.4991 - val_accuracy: 0.8219
# Epoch 4/40
# 19/19 [==============================] - 17s 821ms/step - loss: 0.5139 - accuracy: 0.8399 - val_loss: 0.4734 - val_accuracy: 0.8493
# Epoch 5/40
# 19/19 [==============================] - 17s 818ms/step - loss: 0.4604 - accuracy: 0.8705 - val_loss: 0.4498 - val_accuracy: 0.8356
# Epoch 6/40
# 19/19 [==============================] - 17s 825ms/step - loss: 0.3581 - accuracy: 0.8876 - val_loss: 0.4154 - val_accuracy: 0.8425
# Epoch 7/40
# 19/19 [==============================] - 17s 819ms/step - loss: 0.3621 - accuracy: 0.8807 - val_loss: 0.4078 - val_accuracy: 0.8630
# Epoch 8/40
# Epoch 29/40
# 19/19 [==============================] - 17s 822ms/step - loss: 0.1187 - accuracy: 0.9676 - val_loss: 0.3465 - val_accuracy: 0.8630
# Epoch 30/40
# 19/19 [==============================] - 17s 823ms/step - loss: 0.1157 - accuracy: 0.9710 - val_loss: 0.3270 - val_accuracy: 0.8699
# Epoch 31/40
# 19/19 [==============================] - 17s 827ms/step - loss: 0.1612 - accuracy: 0.9455 - val_loss: 0.3353 - val_accuracy: 0.8904
# Epoch 32/40
# 19/19 [==============================] - 17s 820ms/step - loss: 0.1021 - accuracy: 0.9710 - val_loss: 0.3315 - val_accuracy: 0.8699
# Epoch 33/40
# 19/19 [==============================] - 17s 818ms/step - loss: 0.1212 - accuracy: 0.9625 - val_loss: 0.3503 - val_accuracy: 0.8630
# Epoch 34/40
# 19/19 [==============================] - 17s 823ms/step - loss: 0.1082 - accuracy: 0.9761 - val_loss: 0.3396 - val_accuracy: 0.8562
# Epoch 35/40
# 19/19 [==============================] - 17s 823ms/step - loss: 0.1135 - accuracy: 0.9625 - val_loss: 0.3690 - val_accuracy: 0.8904
# Epoch 36/40
# 19/19 [==============================] - 17s 826ms/step - loss: 0.0932 - accuracy: 0.9693 - val_loss: 0.3078 - val_accuracy: 0.8562
# Epoch 37/40
# 19/19 [==============================] - 17s 825ms/step - loss: 0.1142 - accuracy: 0.9693 - val_loss: 0.3870 - val_accuracy: 0.8836
# Epoch 38/40
# 19/19 [==============================] - 17s 826ms/step - loss: 0.1099 - accuracy: 0.9710 - val_loss: 0.3563 - val_accuracy: 0.8767
# Epoch 39/40
# 19/19 [==============================] - 17s 824ms/step - loss: 0.0966 - accuracy: 0.9779 - val_loss: 0.3609 - val_accuracy: 0.8836
# Epoch 40/40
# 19/19 [==============================] - 17s 823ms/step - loss: 0.1081 - accuracy: 0.9710 - val_loss: 0.3499 - val_accuracy: 0.8699

# %% [markdown]
# #### Ploting Accuracy and Validation Loss

# %%
acc = [0.] + history_resnet50.history['accuracy']
val_acc = [0.] + history_resnet50.history['val_accuracy']

loss = history_resnet50.history['loss']
val_loss = history_resnet50.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy - RESNET50')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss - RESNET50')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## 2.7 Model Comparision<a id='2.7_Model Comparision'></a>

# %% [markdown]
# From the 3 models run above, it is evident that MobileNet v2 and ResNet50 work the best. VGG16 shows the worst performance out of all the three models and takes almost 34 secs per epoch.
#
# Based on the performance, MobileNetV2 has the fastest training time and lowest validation loss. We can use the MobileNetV2 to predict image labels.

# %% [markdown]
# ## 2.8 Model Prediction<a id='2.8_Model Prediction'></a>

# %%
# get and decode the predictions
predicted_batch = model_mobileNetv2.predict(image)
predicted_id = tf.math.argmax(predicted_batch, axis=-1)
predicted_label = class_names[predicted_id]
plt.figure(figsize=(16,16))
plt.subplots_adjust(hspace=0.5)
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(image[i] / 255.0)
    plt.title(predicted_label[i].title())
    plt.axis('off')
    plt.tight_layout
    plt.suptitle('Model predictions')

# %% [markdown]
# ## 2.9 Summary<a id='2.9_Summary'></a>

# %% [markdown]
# As you can see above, the image classifier correctly classified the images above. The overall validation accuracy hovers around 85%, and the business owner of the flower shop is statisfied with this level of accuracy.
