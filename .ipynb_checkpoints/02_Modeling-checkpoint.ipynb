# %% [markdown]
# # 2 Modeling<a id='2_Modeling'></a>

# %% [markdown]
# ## 2.1 Contents<a id='2.1_Contents'></a>
# * [2 Modeling](#2_Modeling)
#     * [2.1 Contents](#2.1_Contents)
#     * [2.2 Imports](#2.2_Imports)
#     * [2.3 Train Validation Split](#2.3_Train_validation)
#     * [2.4 Ploting Training examples](#2.4_Plot_Train)
#     * [2.5 Data Augmentation](#2.5_data_augmentation)
#     * [2.6 Base Model](#2.6_base_model)
#     * [2.7 Pretrained Flower Model](#2.6_flower_model)
#         * [2.7.1 Mobile Net V2](#2.6.1_MobileNetV2)
#         * [2.7.2 VGG16](#2.6.2_VGG16)
#         * [2.7.3 Resnet50](#2.6.3_resnet50)
#     * [2.8 Model Comparison](#2.8_model_comparison)
#     * [2.9 Model Prediction](#2.9_model_prediction)
#     * [2.10 Model Summary](#2.10_model_summary)

# %% [markdown]
# ## 2.2 Imports<a id='2.2_Imports'></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import tensorflow.keras.layers as tfl
import re
import pathlib
import glob
import shutil
import os
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation, RandomZoom

# %%
#Creating folders to save results. If this breaks,create manually
PREPROCESS_FOLDER_PATH = 'preprocessed_data/'

# %% [markdown]
# ## 2.3 Train Validation Split<a id='2.3_Train_validation'></a>

# %%
BATCH_SIZE = 32
IMG_SIZE = (160, 160)
train_dataset = image_dataset_from_directory(PREPROCESS_FOLDER_PATH,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.2,
                                             subset='training',
                                             seed=42)
validation_dataset = image_dataset_from_directory(PREPROCESS_FOLDER_PATH,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.2,
                                             subset='validation',
                                             seed=42)
# Out:
# Found 733 files belonging to 10 classes.
# Using 587 files for training.
# Found 733 files belonging to 10 classes.
# Using 146 files for validation.

# %% [markdown]
# There are **733** images in total. Out of the 733, 80% have been used for training and the other 20% of validation

# %%
#Extracting Classnames from the train dataset
class_names = np.array(train_dataset.class_names)
print(class_names)
# Out:
# ['bougainvillea' 'daisies' 'garden_roses' 'gardenias' 'hibiscus'
#  'hydrangeas' 'lilies' 'orchids' 'peonies' 'tulip']

# %% [markdown]
# ## 2.4 Plot Images and Labels from the Train Dataset<a id='2.4_Plot_Train'></a>

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
#Running an Optimizing Algorithm to find a good allocation of the CPU
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 2.5 Data Augmentation<a id='2.5_data_augmentation'></a>

# %%
#Data Augmentation
def data_augmenter():
    '''
    Create a Sequential model composed of 3 layers
    Random Flip
    Random Rotate
    Random Zoom
    
    Returns:
        tf.keras.Sequential
    '''
    data_augmentation = tf.keras.Sequential()
    data_augmentation.add(RandomFlip('horizontal'))
    data_augmentation.add(RandomRotation(0.2))
    data_augmentation.add(RandomZoom(0.5, 0.2))
    
    return data_augmentation

# %%
#Initialize the augmenter
augmenter = data_augmenter()

# %%
#Plot the augmented data
data_augmentation = data_augmenter()

for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %% [markdown]
# ## 2.6 Base Model<a id='2.6_base_model'></a>

# %%
def my_model(IMG_SIZE):
    """
    Implements the forward propagation for the binary classification model:
    ZEROPAD2D -> CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code all the values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    None

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """
    
    input_shape = IMG_SIZE + (3, )
    inputs = tf.keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = tf.keras.layers.Conv2D(filters = 64, kernel_size = (4, 4), strides = (1, 1), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis = 3)(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.MaxPool2D(pool_size = (8, 8), strides = (8, 8), padding = 'same')(x)
    x = tf.keras.layers.Conv2D(filters = 128, kernel_size = (2, 2), strides = (1, 1), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis = 3)(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.MaxPool2D(pool_size = (4, 4), strides = (4, 4), padding = 'same')(x)
    x = tf.keras.layers.Conv2D(filters = 256, kernel_size = (2, 2), strides = (1, 1), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis = 3)(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.MaxPool2D(pool_size = (2, 2), strides = (2, 2), padding = 'same')(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x) 
    #Added New to reduce Overfitting
    x = tf.keras.layers.Dropout(0.2)(x)
    x = tf.keras.layers.Flatten()(x) 

    outputs = tf.keras.layers.Dense(10, activation = 'softmax')(x)
    
    model = tf.keras.Model(inputs = inputs, outputs = outputs)
    
    return model

# %%
base_model = my_model(IMG_SIZE)

# %%
base_model.compile(optimizer=tf.keras.optimizers.Adam(lr = 0.0005),
               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
               metrics=['accuracy'])
# Out:
# C:\Users\Neel Deorukhkar\Documents\Anaconda\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
base_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential_1 (Sequential)   (None, 160, 160, 3)       0
#
#  conv2d (Conv2D)             (None, 160, 160, 64)      3136
#
#  batch_normalization (BatchN  (None, 160, 160, 64)     256
#  ormalization)
#
#  re_lu (ReLU)                (None, 160, 160, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 20, 20, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 20, 20, 128)       32896
#
#  batch_normalization_1 (Batc  (None, 20, 20, 128)      512
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 20, 20, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 5, 5, 256)         131328
#
#  batch_normalization_2 (Batc  (None, 5, 5, 256)        1024
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 5, 5, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 256)               0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 10)                2570
#
# =================================================================
# Total params: 171,722
# Trainable params: 170,826
# Non-trainable params: 896
# _________________________________________________________________

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=25)

# %%
history = base_model.fit(train_dataset, epochs=70, batch_size=32, validation_data=validation_dataset, callbacks=[es])
# Out:
# C:\Users\Neel Deorukhkar\Documents\Anaconda\lib\site-packages\tensorflow\python\util\dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# Epoch 1/100
# 19/19 [==============================] - 11s 483ms/step - loss: 2.0694 - accuracy: 0.2794 - val_loss: 14.2399 - val_accuracy: 0.1096
# Epoch 2/100
# 19/19 [==============================] - 11s 501ms/step - loss: 1.5893 - accuracy: 0.4685 - val_loss: 8.9782 - val_accuracy: 0.1096
# Epoch 3/100
# 19/19 [==============================] - 11s 511ms/step - loss: 1.4437 - accuracy: 0.4940 - val_loss: 7.1531 - val_accuracy: 0.1096
# Epoch 4/100
# 19/19 [==============================] - 10s 488ms/step - loss: 1.3094 - accuracy: 0.5639 - val_loss: 2.9024 - val_accuracy: 0.2192
# Epoch 5/100
# 19/19 [==============================] - 10s 488ms/step - loss: 1.1719 - accuracy: 0.6099 - val_loss: 3.4132 - val_accuracy: 0.1918
# Epoch 6/100
# 19/19 [==============================] - 10s 478ms/step - loss: 1.1399 - accuracy: 0.6354 - val_loss: 2.2176 - val_accuracy: 0.3356
# Epoch 7/100
# 19/19 [==============================] - 10s 477ms/step - loss: 1.0960 - accuracy: 0.6525 - val_loss: 1.8906 - val_accuracy: 0.3904
# 19/19 [==============================] - 11s 534ms/step - loss: 0.3318 - accuracy: 0.8842 - val_loss: 1.3377 - val_accuracy: 0.6849
# Epoch 85/100
# 19/19 [==============================] - 11s 535ms/step - loss: 0.3134 - accuracy: 0.9046 - val_loss: 1.4449 - val_accuracy: 0.6849
# Epoch 86/100
# 19/19 [==============================] - 11s 530ms/step - loss: 0.2969 - accuracy: 0.9216 - val_loss: 1.7357 - val_accuracy: 0.6233
# Epoch 87/100
# 19/19 [==============================] - 11s 532ms/step - loss: 0.2767 - accuracy: 0.9165 - val_loss: 1.3227 - val_accuracy: 0.6918

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(history.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# C:\Users\Neel Deorukhkar\Documents\Anaconda\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# [Text(0, 0.5, 'Accuracy'), Text(0.5, 0, 'Epoch')]

# %%
base_model.evaluate(validation_dataset)
# Out:
# 5/5 [==============================] - 1s 94ms/step - loss: 1.3227 - accuracy: 0.6918
# [1.3227030038833618, 0.6917808055877686]

# %% [markdown]
# ### Analyzing the base model output

# %% [markdown]
# As we can see above, the base model overfits the the training dataset. The training accuracy is around 98% whereas the validation accuracy is at 69%.
#
# Initially, I the validation accuracy was hovering around 40%. I used the following steps to improve the validation accuracy and improve validation loss:
#
# 1. Added Additional Convolutional layers --> CONV2D --> BATCHNORM --> RELU --> MAXPOOL2D   x 3
# 2. Increased the number of filters in each additional layer
# 3. Data Augmentation -- RandomFlip, RandomRotation and RandomZoom
# 4. To reduce Overfitting, I added a dropout of 0.2
#
# So by adding new layers, increasing the number of filters, curating more data , we've been able to improve the model validation accuracy from 40% to almost 70%.
#
# However, from a business perspective, 70% accuracy on the validation is not something the business owner is comfortable as that leads to a high misclassification rate.

# %% [markdown]
# **Based on the findings above, it's faster for us to use a pretrained model from Keras Applications and modify the pretrained model to reduce validation loss. We can do this by dropping the last softmax layer, and modifying the Dense layer to include only the number of classes**

# %% [markdown]
# ## 2.7 Pretrained Flower Model<a id='2.6_flower_model'></a>

# %%
def flowers_model(image_shape=IMG_SIZE,
                  data_augmentation=data_augmenter(),
                  pretrained_model = tf.keras.applications.mobilenet_v2.MobileNetV2,
                  preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input,
                  num_classes = len(class_names)):
    ''' Define a tf.keras model for Multi classification out of the flowers model
    Arguments:
        image_shape -- Image width and height
        data_augmentation -- data augmentation function
        keras.applications -- Pretrainied Model
        keras.application.preprocess_input -- Preprocess the data
    Returns:
        tf.keras.model    '''    
    
    input_shape = image_shape + (3,)
        
    base_model = pretrained_model(input_shape=input_shape,
                                  include_top=False,
                                  weights='imagenet')
    
    # Freezing the Base model
    base_model.trainable = False 

    # Creating the Input layer as the same size as ImageNetV2
    inputs = tf.keras.Input(shape=input_shape) 
    
    # Data Augmemtation
    x = data_augmentation(inputs)
    
    # Preprocessing the data using the same weights as the pretrained model
    x = preprocess_input(x) 
    
    x = base_model(x, training=False)     
    x = tf.keras.layers.GlobalAveragePooling2D()(x) 
    x = tf.keras.layers.Dropout(0.2)(x)
     
    #Softmax for Multiclass    
    outputs = tf.keras.layers.Dense(num_classes, activation = 'softmax')(x)
    
    model = tf.keras.Model(inputs, outputs)
    
    return model

# %% [markdown]
# ### 2.7.1 MobileNetV2<a id='2.6.1_MobileNetV2'></a>

# %%
model_mobileNetv2 = flowers_model(IMG_SIZE, data_augmentation)

# %%
model_mobileNetv2.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential_1 (Sequential)   (None, 160, 160, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 160, 160, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 160, 160, 3)      0
#  a)
#
#  mobilenetv2_1.00_160 (Funct  (None, 5, 5, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_1   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense_1 (Dense)             (None, 10)                12810
#
# =================================================================
# Total params: 2,270,794
# Trainable params: 12,810
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model_mobileNetv2.compile(optimizer=tf.keras.optimizers.Adam(lr = 0.001),
               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
               metrics=['accuracy'])

# %%
initial_epochs = 70
history = model_mobileNetv2.fit(train_dataset, validation_data=validation_dataset, epochs=initial_epochs, callbacks= [es])
# Out:
# Epoch 1/40
# C:\Users\Neel Deorukhkar\Documents\Anaconda\lib\site-packages\tensorflow\python\util\dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 19/19 [==============================] - 9s 312ms/step - loss: 2.1957 - accuracy: 0.2726 - val_loss: 1.3198 - val_accuracy: 0.6096
# Epoch 2/40
# 19/19 [==============================] - 6s 277ms/step - loss: 1.1681 - accuracy: 0.6286 - val_loss: 0.8432 - val_accuracy: 0.7534
# Epoch 3/40
# 19/19 [==============================] - 6s 279ms/step - loss: 0.7487 - accuracy: 0.7922 - val_loss: 0.6783 - val_accuracy: 0.8082
# Epoch 4/40
# 19/19 [==============================] - 7s 333ms/step - loss: 0.5928 - accuracy: 0.8177 - val_loss: 0.5747 - val_accuracy: 0.8288
# Epoch 5/40
# 19/19 [==============================] - 7s 304ms/step - loss: 0.4984 - accuracy: 0.8552 - val_loss: 0.5577 - val_accuracy: 0.8151
# Epoch 6/40
# 19/19 [==============================] - 7s 301ms/step - loss: 0.4396 - accuracy: 0.8722 - val_loss: 0.5246 - val_accuracy: 0.8219
# Epoch 7/40
# 19/19 [==============================] - 7s 308ms/step - loss: 0.4233 - accuracy: 0.8722 - val_loss: 0.4669 - val_accuracy: 0.8425
# Epoch 8/40
# 19/19 [==============================] - 6s 280ms/step - loss: 0.3636 - accuracy: 0.8944 - val_loss: 0.4640 - val_accuracy: 0.8562
# Epoch 9/40
# 19/19 [==============================] - 6s 283ms/step - loss: 0.3292 - accuracy: 0.9012 - val_loss: 0.4540 - val_accuracy: 0.8562
# Epoch 10/40
# 19/19 [==============================] - 6s 279ms/step - loss: 0.3031 - accuracy: 0.9029 - val_loss: 0.4255 - val_accuracy: 0.8425
# Epoch 11/40
# 19/19 [==============================] - 6s 289ms/step - loss: 0.3132 - accuracy: 0.9182 - val_loss: 0.4319 - val_accuracy: 0.8699
# Epoch 12/40
# 19/19 [==============================] - 6s 286ms/step - loss: 0.2802 - accuracy: 0.9046 - val_loss: 0.4412 - val_accuracy: 0.8562
# Epoch 13/40
# 19/19 [==============================] - 6s 281ms/step - loss: 0.2451 - accuracy: 0.9284 - val_loss: 0.4054 - val_accuracy: 0.8699
# Epoch 14/40
# 19/19 [==============================] - 6s 282ms/step - loss: 0.1318 - accuracy: 0.9693 - val_loss: 0.3348 - val_accuracy: 0.8699
# Epoch 34/40
# 19/19 [==============================] - 6s 284ms/step - loss: 0.1198 - accuracy: 0.9676 - val_loss: 0.3984 - val_accuracy: 0.8699
# Epoch 35/40
# 19/19 [==============================] - 7s 292ms/step - loss: 0.1014 - accuracy: 0.9796 - val_loss: 0.3499 - val_accuracy: 0.8767
# Epoch 36/40
# 19/19 [==============================] - 7s 306ms/step - loss: 0.1077 - accuracy: 0.9779 - val_loss: 0.3564 - val_accuracy: 0.8767
# Epoch 37/40
# 19/19 [==============================] - 7s 293ms/step - loss: 0.1110 - accuracy: 0.9659 - val_loss: 0.3800 - val_accuracy: 0.8767
# Epoch 38/40
# 19/19 [==============================] - 6s 286ms/step - loss: 0.1210 - accuracy: 0.9591 - val_loss: 0.3353 - val_accuracy: 0.8836
# Epoch 39/40
# 19/19 [==============================] - 6s 280ms/step - loss: 0.1132 - accuracy: 0.9727 - val_loss: 0.3925 - val_accuracy: 0.8630
# Epoch 40/40
# 19/19 [==============================] - 6s 282ms/step - loss: 0.1038 - accuracy: 0.9779 - val_loss: 0.3387 - val_accuracy: 0.8836

# %%
model_mobileNetv2.evaluate(validation_dataset)
# Out:
# 5/5 [==============================] - 1s 138ms/step - loss: 0.3387 - accuracy: 0.8836
# [0.33874282240867615, 0.8835616707801819]

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(16, 5))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy - Mobile Net V2')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,2.5])
plt.title('Training and Validation Loss - Mobile Net V2')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Analyzing the MobileNetv2 model output

# %% [markdown]
# Clearly, using a pretrained model has saved time and increased the validation accuracy to 90%. The business owner is much satisfied with the results, and accepts an accuracy of 90%.
#
# The time per epoch is 300 ms which is pretty fast.

# %% [markdown]
# We could try different pretrained models to see whether the accuracy improves

# %% [markdown]
# ## 2.7.2 VGG16 <a id='2.6.2_VGG16'></a>

# %%
model_vgg16 = flowers_model(IMG_SIZE, data_augmentation,
                           pretrained_model = tf.keras.applications.vgg16.VGG16,
                           preprocess_input = tf.keras.applications.vgg16.preprocess_input)
model_vgg16.compile(optimizer=tf.keras.optimizers.Adam(lr = 0.001),
               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
               metrics=['accuracy'])
initial_epochs = 70
history_vgg16 = model_vgg16.fit(train_dataset, validation_data=validation_dataset, epochs=initial_epochs)
# Out:
# Epoch 1/20
# 19/19 [==============================] - 31s 2s/step - loss: 8.3531 - accuracy: 0.0903 - val_loss: 6.0319 - val_accuracy: 0.1781
# Epoch 2/20
# 19/19 [==============================] - 32s 2s/step - loss: 5.8039 - accuracy: 0.1925 - val_loss: 4.2224 - val_accuracy: 0.2671
# Epoch 3/20
# 19/19 [==============================] - 33s 2s/step - loss: 4.3522 - accuracy: 0.2709 - val_loss: 3.0214 - val_accuracy: 0.4110
# Epoch 4/20
# 19/19 [==============================] - 33s 2s/step - loss: 3.2186 - accuracy: 0.3952 - val_loss: 2.2870 - val_accuracy: 0.4795
# Epoch 5/20
# 19/19 [==============================] - 33s 2s/step - loss: 2.7907 - accuracy: 0.4395 - val_loss: 1.8262 - val_accuracy: 0.5890
# Epoch 6/20
# 19/19 [==============================] - 32s 2s/step - loss: 2.0992 - accuracy: 0.5298 - val_loss: 1.6499 - val_accuracy: 0.6781
# Epoch 7/20
# 19/19 [==============================] - 32s 2s/step - loss: 2.0383 - accuracy: 0.5332 - val_loss: 1.5410 - val_accuracy: 0.6849
# Epoch 8/20
# 19/19 [==============================] - 33s 2s/step - loss: 1.5662 - accuracy: 0.6099 - val_loss: 1.4149 - val_accuracy: 0.7055
# Epoch 9/20
# 19/19 [==============================] - 31s 2s/step - loss: 1.4683 - accuracy: 0.6440 - val_loss: 1.3403 - val_accuracy: 0.7329
# Epoch 10/20
# 19/19 [==============================] - 31s 2s/step - loss: 1.4098 - accuracy: 0.6559 - val_loss: 1.3165 - val_accuracy: 0.7466
# Epoch 11/20
# 19/19 [==============================] - 31s 2s/step - loss: 1.2337 - accuracy: 0.7002 - val_loss: 1.1529 - val_accuracy: 0.7603
# Epoch 12/20
# 19/19 [==============================] - 33s 2s/step - loss: 1.1276 - accuracy: 0.6985 - val_loss: 1.1345 - val_accuracy: 0.7808
# Epoch 13/20
# 19/19 [==============================] - 31s 2s/step - loss: 1.1546 - accuracy: 0.7087 - val_loss: 1.1594 - val_accuracy: 0.7671
# Epoch 14/20
# 19/19 [==============================] - 32s 2s/step - loss: 1.0402 - accuracy: 0.7257 - val_loss: 1.1529 - val_accuracy: 0.7534
# Epoch 15/20
# 19/19 [==============================] - 31s 2s/step - loss: 0.9644 - accuracy: 0.7530 - val_loss: 1.0069 - val_accuracy: 0.7808
# Epoch 16/20
# 19/19 [==============================] - 31s 2s/step - loss: 0.9207 - accuracy: 0.7547 - val_loss: 1.0256 - val_accuracy: 0.7877
# Epoch 17/20
# 19/19 [==============================] - 31s 2s/step - loss: 0.7720 - accuracy: 0.7717 - val_loss: 0.9180 - val_accuracy: 0.8014
# Epoch 18/20
# 19/19 [==============================] - 31s 2s/step - loss: 0.8687 - accuracy: 0.7734 - val_loss: 0.8790 - val_accuracy: 0.8082
# Epoch 19/20
# 19/19 [==============================] - 32s 2s/step - loss: 0.7561 - accuracy: 0.7853 - val_loss: 0.9356 - val_accuracy: 0.8082
# Epoch 20/20
# 19/19 [==============================] - 31s 2s/step - loss: 0.6873 - accuracy: 0.7939 - val_loss: 0.8432 - val_accuracy: 0.8014

# %%
model_vgg16.evaluate(validation_dataset)
# Out:
# 5/5 [==============================] - 6s 1s/step - loss: 0.8432 - accuracy: 0.8014
# [0.8431639075279236, 0.801369845867157]

# %% [markdown]
# #### Ploting Accuracy and Validation Loss

# %%
acc = [0.] + history_vgg16.history['accuracy']
val_acc = [0.] + history_vgg16.history['val_accuracy']

loss = history_vgg16.history['loss']
val_loss = history_vgg16.history['val_loss']

plt.figure(figsize=(16, 5))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy - VGG16')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0, 2.5])
plt.title('Training and Validation Loss - VGG16')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Analyzing the VGG16 model output

# %% [markdown]
# The VGG16 model is much slower than the MobileNetV2 model because of the size of the network and number of parameters. Secondly, the model predicts better than the base model but much more poorly than the MobileNetV2 model.

# %% [markdown]
# This gives a sense that not all pretrained models work in the similar way. We can try out the ResNet50 model next to see the performance

# %% [markdown]
# ## 2.7.3 ResNet50 <a id='2.6.3_resnet50'></a>

# %%
model_resnet50 = flowers_model(IMG_SIZE, data_augmentation,
                           pretrained_model = tf.keras.applications.resnet50.ResNet50,
                           preprocess_input = tf.keras.applications.resnet50.preprocess_input)
model_resnet50.compile(optimizer=tf.keras.optimizers.Adam(lr = 0.001),
               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
               metrics=['accuracy'])
initial_epochs = 70
history_resnet50 = model_resnet50.fit(train_dataset, validation_data=validation_dataset, epochs=initial_epochs)
# Out:
# Epoch 1/40
# 19/19 [==============================] - 18s 774ms/step - loss: 2.3765 - accuracy: 0.2709 - val_loss: 1.2211 - val_accuracy: 0.5959
# Epoch 2/40
# 19/19 [==============================] - 18s 873ms/step - loss: 1.0719 - accuracy: 0.6525 - val_loss: 0.6930 - val_accuracy: 0.7671
# Epoch 3/40
# 19/19 [==============================] - 17s 833ms/step - loss: 0.7216 - accuracy: 0.7768 - val_loss: 0.5657 - val_accuracy: 0.8082
# Epoch 4/40
# 19/19 [==============================] - 16s 769ms/step - loss: 0.6052 - accuracy: 0.8058 - val_loss: 0.4977 - val_accuracy: 0.8082
# Epoch 5/40
# 19/19 [==============================] - 16s 818ms/step - loss: 0.4818 - accuracy: 0.8637 - val_loss: 0.4498 - val_accuracy: 0.8288
# Epoch 6/40
# 19/19 [==============================] - 16s 804ms/step - loss: 0.4257 - accuracy: 0.8688 - val_loss: 0.4273 - val_accuracy: 0.8151
# Epoch 7/40
# 19/19 [==============================] - 16s 776ms/step - loss: 0.3484 - accuracy: 0.8995 - val_loss: 0.3935 - val_accuracy: 0.8356
# Epoch 8/40
# 19/19 [==============================] - 15s 767ms/step - loss: 0.2850 - accuracy: 0.9097 - val_loss: 0.3999 - val_accuracy: 0.8219
# Epoch 9/40
# 19/19 [==============================] - 16s 795ms/step - loss: 0.3045 - accuracy: 0.8910 - val_loss: 0.3869 - val_accuracy: 0.8356
# Epoch 10/40
# 19/19 [==============================] - 16s 810ms/step - loss: 0.2750 - accuracy: 0.9148 - val_loss: 0.3763 - val_accuracy: 0.8219
# Epoch 11/40
# 19/19 [==============================] - 16s 782ms/step - loss: 0.2583 - accuracy: 0.9046 - val_loss: 0.3899 - val_accuracy: 0.8425
# Epoch 12/40
# 19/19 [==============================] - 16s 813ms/step - loss: 0.2742 - accuracy: 0.9114 - val_loss: 0.3825 - val_accuracy: 0.8493
# Epoch 13/40
# 19/19 [==============================] - 16s 815ms/step - loss: 0.2554 - accuracy: 0.9250 - val_loss: 0.3767 - val_accuracy: 0.8493
# Epoch 14/40
# 19/19 [==============================] - 16s 802ms/step - loss: 0.2215 - accuracy: 0.9404 - val_loss: 0.3589 - val_accuracy: 0.8288
# Epoch 15/40
# 19/19 [==============================] - 16s 812ms/step - loss: 0.2090 - accuracy: 0.9353 - val_loss: 0.4146 - val_accuracy: 0.8630
# Epoch 35/40
# 19/19 [==============================] - 16s 809ms/step - loss: 0.1007 - accuracy: 0.9710 - val_loss: 0.3663 - val_accuracy: 0.8630
# Epoch 36/40
# 19/19 [==============================] - 16s 779ms/step - loss: 0.0902 - accuracy: 0.9813 - val_loss: 0.3456 - val_accuracy: 0.8836
# Epoch 37/40
# 19/19 [==============================] - 16s 804ms/step - loss: 0.1141 - accuracy: 0.9710 - val_loss: 0.4157 - val_accuracy: 0.8699
# Epoch 38/40
# 19/19 [==============================] - 16s 795ms/step - loss: 0.1068 - accuracy: 0.9744 - val_loss: 0.4264 - val_accuracy: 0.8562
# Epoch 39/40
# 19/19 [==============================] - 15s 760ms/step - loss: 0.0943 - accuracy: 0.9710 - val_loss: 0.3673 - val_accuracy: 0.8562
# Epoch 40/40
# 19/19 [==============================] - 16s 788ms/step - loss: 0.0917 - accuracy: 0.9796 - val_loss: 0.4081 - val_accuracy: 0.8493

# %% [markdown]
# #### Ploting Accuracy and Validation Loss

# %%
model_resnet50.evaluate(validation_dataset)
# Out:
# 5/5 [==============================] - 3s 527ms/step - loss: 0.4081 - accuracy: 0.8493
# [0.4080662429332733, 0.8493150472640991]

# %%
acc = [0.] + history_resnet50.history['accuracy']
val_acc = [0.] + history_resnet50.history['val_accuracy']

loss = history_resnet50.history['loss']
val_loss = history_resnet50.history['val_loss']

plt.figure(figsize=(16, 5))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy - RESNET50')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,2.5])
plt.title('Training and Validation Loss - RESNET50')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Analyzing the ResNet50 model output

# %% [markdown]
# The Resnet50 model does better than the base model and VGG16 model and has an overall validation accuracy of 84%. This is pretty good, but the Mobile V2 Model is the best in terms of accuracy and lowest validation loss.

# %% [markdown]
# ## 2.8 Model Comparison<a id='2.8_model_comparison'></a>

# %% [markdown]
# |Model||Validation_Accuracy||Validation_loss||Time per Epoch|
# |-----||-------------------||---------------||--------------|
# |base_model||70%           ||1.32           || 500ms        |
# |**MobileNetV2**||**89%**          ||**0.35**           || **350ms**        |
# |VGG16||78%||1.05||34s|
# |ResNet50||84%||0.38||786ms|

# %% [markdown]
# From the 3 models run above, it is evident that MobileNet v2 and ResNet50 work the best. VGG16 shows the worst performance out of all the three models and takes almost 34 secs per epoch.
#
# Based on the performance, MobileNetV2 has the fastest training time and lowest validation loss. We can use the MobileNetV2 to predict image labels.

# %% [markdown]
# ## 2.9 Model Prediction<a id='2.9_model_prediction'></a>

# %%
# get and decode the predictions
predicted_batch = model_mobileNetv2.predict(image)
predicted_id = tf.math.argmax(predicted_batch, axis=-1)
predicted_label = class_names[predicted_id]
plt.figure(figsize=(12,12))
plt.subplots_adjust(hspace=0.5)
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(image[i] / 255.0)
    plt.title(predicted_label[i].title())
    plt.axis('off')
    plt.tight_layout
    plt.suptitle('Model predictions')

# %% [markdown]
# ## 2.10 Summary<a id='2.10_model_summary'></a>

# %% [markdown]
# As you can see above, the image classifier correctly classified the images above. The overall validation accuracy hovers around 85%, and the business owner of the flower shop is statisfied with this level of accuracy.
